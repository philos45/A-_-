# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
data=pd.read_excel("연령성별구분.xlsx")

# %%
data.groupby("구분.1")

# %%
data.columns
# Out:
# Index(['구분', '구분.1', '계'], dtype='object')

# %%
data.head(2)
# Out:
#     구분 구분.1  계
# 0   9세    남  1
# 1  99세    남  0

# %%
fig = plt.figure(figsize=(25, 20))
plt.bar(data["계"],data["구분"])
# Out:
# <BarContainer object of 202 artists>

# %%
col_list=data["Age"].values
colu = list(set(col_list))
colu.sort()

# %%
plt.figure(figsize=(8,5))
plt.title("연령+성별 환자수 (2010~2019)", fontsize=16)
plt.plot(colu,여성["Patient"],color="red",ls="--",marker="o",lw=3,markerfacecolor="yellow")
plt.plot(colu,남성["Patient"],color="blue",ls=":",marker="*",lw=4,markerfacecolor="black")
plt.xlabel("연령대",labelpad=10, fontsize="x-large")
plt.ylabel("환자 수",labelpad=25,rotation=-360, fontsize="x-large")
plt.legend("女男")
plt.grid()
